# %%
import os
# Modulo onde fara com que localizemos o spark na maquina, junto com outros arquivos
import findspark

# Definindo o caminho onde se encontram os arquivos em uma váriavel de ambiente
os.environ['SPARK_HOME'] = 'C:\spark\spark-3.4.0-bin-hadoop3'
# Setando o caminho onde o java esta instalado
os.environ['JAVA_HOME'] = 'C:\Program Files\Java\jre-1.8'

findspark.init()

from pyspark.sql import SparkSession, functions as F
from pyspark.sql.types import DoubleType, StringType

# %%
# Cria a sessão indicando para rodar localmente e criar as CPUs possíveis
spark = SparkSession.builder \
    .master('local[*]') \
    .appName('Create Session') \
    .config('spark.ui.port', '4050') \
    .getOrCreate()

# %%
# Por padrao o spark espera um json de uma linha apenas, por conta disso ajustamos o multine
# Ao utilizar o * eu posso ler va
df_2020 = spark.read.option("multiline", "true").json(os.getcwd() + r"\dados\response_2020.json")

# %%
# Por padrao o spark espera um json de uma linha apenas, por conta disso ajustamos o multine
# Ao utilizar o * eu posso ler va
df_2021 = spark.read.option("multiline", "true").json(os.getcwd() + r"\dados\response_2021.json")

# %%
# Por padrao o spark espera um json de uma linha apenas, por conta disso ajustamos o multine
# Ao utilizar o * eu posso ler va
df_2022 = spark.read.option("multiline", "true").json(os.getcwd() + r"\dados\response_2022.json")

# %%
df_2020.show()
# Out:
# +--------------------+
# |           resultado|
# +--------------------+
# |{MATE, (2020)[ANO...|
# +--------------------+

# %%
df_2020.collect()
# Out:
# [Row(resultado=Row(banco='MATE', consulta='(2020)[ANO]', dataHora=Row(date='2022-10-19'), erro=False, listaItem=[Row(acompanhamento='N', ano='2020', apelido=None, arquivamento='20210224', assunto='Indica Vívia Paula Diniz Abreu para compor o Conselho Estadual de\nEducação.', assuntoGeral='Conselho Estadual', atualizacao='20210224', atualizacaoTexto=None, autor='Governador Romeu Zema Neto', classificacao=None, dataPublicacao='2020-03-12', dataUltimaAcao='2021-02-04', dominio='Remissivo', edicao=None, horario='1528', horarioTexto=None, indexacao='Indicação, Membro, Conselho Estadual de Educação (CEE).', legislacaoCitada=None, linkProposicaoAnexadora=None, links=[Row(ano=2021, banco='mate', descricao='RQO 985 2021', expressao="(RQO adj '985' adj 2021[PROP])[dbmt]", numero=985, tipo='RQO', url='/proposicoes/pesquisa/avancada?expr=%28RQO+adj+%27985%27+adj+2021%5BPROP%5D%29%5Bdbmt%5D'), Row(ano=2021, banco='mate', descricao='MSG 115 2021', expressao="(MSG adj '115' adj 2021[PROP])[dbmt]", numero=115, tipo='MSG', url='/proposicoes/pesquisa/avancada?expr=%28MSG+adj+%27115%27+adj+2021%5BPROP%5D%29%5Bdbmt%5D')], linksOrigem=[Row(ano=2020, banco='mate', descricao='MSG 71 2020', expressao="(MSG adj '71' adj 2020[PROP])[dbmt]", numero=71, tipo='MSG', url='/proposicoes/pesquisa/avancada?expr=%28MSG+adj+%2771%27+adj+2020%5BPROP%5D%29%5Bdbmt%5D')], linksProposicoesAnexadas=[], linksTextos=[Row(banco='mate', descricao='Proposição', expressao='(IND20200002801[codi])[txmt]', url='/proposicoes/pesquisa/avancada?expr=%28IND20200002801%5Bcodi%5D%29%5Btxmt%5D&pesqProp=true')], listaHistoricoTramitacoes=[Row(data='2021-02-04', historico='Requerimento do autor solicitando a retirada de tramitação da\nproposição. Deferido. Arquive-se.\nDecisão publicada no DL em 6 2 2021, pág 42.', local='Plenário', passo=4), Row(data='2020-10-21', historico='Relator: Dep. Professor Irineu.', local='Comissão Especial', passo=3), Row(data='2020-10-08', historico='Designada a Comissão Especial, conforme acordo de líderes acolhido\npela Presidência em 8 10 2020, publicado no DL em 10 10 2020, pág.\n8.\nComponentes: Pelo Bloco Sou Minas Gerais – BSMG: Efetivos: Dep.\nProfessor Wendel Mesquita e Dep. Professor Cleiton; Suplentes: Dep.\nRaul Belém e Dep. João Vítor Xavier; Pelo Bloco Minas tem História -\nBMTH: Efetivo: Dep. João Magalhães; Suplente: Dep. Hely Tarqüínio;\nPelo\nBloco Liberdade e Progresso - BLP: Efetivo: Dep. Professor Irineu;\nSuplente: Dep. Delegada Sheila; Pelo Bloco Democracia e Luta - BDL:\nEfetivo: Dep. Beatriz Cerqueira; Suplente: Dep. Betão.\nRecebida na ESP em 10 10 2020.', local='Plenário', passo=2), Row(data='2020-03-10', historico='Proposição recebida em Plenário.\nPublicada no DL em 12 3 2020, pág 5.\nÀ Comissão Especial, para parecer.', local='Plenário', passo=1)], local='Arquivo', matricula='', numero='28', numeroDoc='000016448', observacao='Distribuída a 1 comissão: ESP.', proposicao='IND 28 2020 - INDICAÇÃO', regime='Especial', siglaSituacao='RETRA', siglaSituacaoGeral='MOUTR', siglaTipoProjeto='IND', situacao='Retirado de tramitação', situacaoGeral='Outras situações', tema='Administração Pública', tipoProjeto='INDICAÇÃO', usuario='m20725', usuarioTexto=None), Row(acompanhamento='N', ano='2020', apelido=None, arquivamento=None, assunto='Indica Paulo Henrique Cotta Pacheco para compor o Conselho Estadual de\nEducação.', assuntoGeral='Conselho Estadual', atualizacao='20220412', atualizacaoTexto=None, autor='Governador Romeu Zema Neto', classificacao=None, dataPublicacao='2020-03-12', dataUltimaAcao='2022-03-31', dominio='Tramitação', edicao=None, horario='1039', horarioTexto=None, indexacao='Indicação, Membro, Conselho Estadual de Educação (CEE).', legislacaoCitada=None, linkProposicaoAnexadora=None, links=[], linksOrigem=[Row(ano=2020, banco='mate', descricao='MSG 71 2020', expressao="(MSG adj '71' adj 2020[PROP])[dbmt]", numero=71, tipo='MSG', url='/proposicoes/pesquisa/avancada?expr=%28MSG+adj+%2771%27+adj+2020%5BPROP%5D%29%5Bdbmt%5D')], li ...

# %%
# Dentro do campo struct temos o campo que queremos que é o listaItem, que é um array, por conta disso que precisamos dar um explode nele
df_2020 = df_2020.select(F.explode(F.col('resultado.listaItem')))\
    .select('col.*')

df_2021 = df_2021.select(F.explode(F.col('resultado.listaItem')))\
    .select('col.*')

df_2022 = df_2022.select(F.explode(F.col('resultado.listaItem')))\
    .select('col.*')

# %%
# Utilizando o UnionByName, pois os arquivos possuem colunas diferentes,
# Desta forma ele empilha e preenche com valores nulos que nao tiverem
df_final = df_2020.unionByName(df_2021, allowMissingColumns=True).\
    unionByName(df_2022, allowMissingColumns=True)

# %%
df_final.show(5)
# Out:
# +--------------+----+-------+------------+--------------------+-----------------+-----------+----------------+--------------------+-------------+--------------+--------------+----------+------+-------+------------+--------------------+----------------+-----------------------+--------------------+--------------------+------------------------+--------------------+-------------------------+-----------------+---------+------+---------+--------------------+--------------------+--------+-------------+------------------+----------------+--------------------+--------------------+--------------------+-----------+-------+------------+----+
# |acompanhamento| ano|apelido|arquivamento|             assunto|     assuntoGeral|atualizacao|atualizacaoTexto|               autor|classificacao|dataPublicacao|dataUltimaAcao|   dominio|edicao|horario|horarioTexto|           indexacao|legislacaoCitada|linkProposicaoAnexadora|               links|         linksOrigem|linksProposicoesAnexadas|         linksTextos|listaHistoricoTramitacoes|            local|matricula|numero|numeroDoc|          observacao|          proposicao|  regime|siglaSituacao|siglaSituacaoGeral|siglaTipoProjeto|            situacao|       situacaoGeral|                tema|tipoProjeto|usuario|usuarioTexto|nome|
# +--------------+----+-------+------------+--------------------+-----------------+-----------+----------------+--------------------+-------------+--------------+--------------+----------+------+-------+------------+--------------------+----------------+-----------------------+--------------------+--------------------+------------------------+--------------------+-------------------------+-----------------+---------+------+---------+--------------------+--------------------+--------+-------------+------------------+----------------+--------------------+--------------------+--------------------+-----------+-------+------------+----+
# |             N|2020|   null|    20210224|Indica Vívia Paul...|Conselho Estadual|   20210224|            null|Governador Romeu ...|         null|    2020-03-12|    2021-02-04| Remissivo|  null|   1528|        null|Indicação, Membro...|            null|                   null|[{2021, mate, RQO...|[{2020, mate, MSG...|                      []|[{mate, Proposiçã...|     [{2021-02-04, Req...|          Arquivo|         |    28|000016448|Distribuída a 1 c...|IND 28 2020 - IND...|Especial|        RETRA|             MOUTR|             IND|Retirado de trami...|    Outras situações|Administração Púb...|  INDICAÇÃO| m20725|        null|null|
# |             N|2020|   null|        null|Indica Paulo Henr...|Conselho Estadual|   20220412|            null|Governador Romeu ...|         null|    2020-03-12|    2022-03-31|Tramitação|  null|   1039|        null|Indicação, Membro...|            null|                   null|                  []|[{2020, mate, MSG...|                      []|[{mate, Proposiçã...|     [{2022-03-31, Rem...|Comissão Especial|         |    27|000016449|Distribuída a 1 c...|IND 27 2020 - IND...|Especial|        AGDLC|             MAPCO|             IND|Aguardando diligê...|Aguardando apreci...|Administração Púb...|  INDICAÇÃO| moreka|        null|null|
# |             N|2020|   null|        null|Indica Gabriel Le...|Conselho Estadual|   20220915|            null|Governador Romeu ...|         null|    2020-03-12|    2022-09-13|Tramitação|  null|   0752|        null|Indicação, Membro...|            null|                   null|                  []|[{2020, mate, MSG...|                      []|[{mate, Proposiçã...|     [{2022-09-13, Ofí...|Comissão Especial|         |    26|000016450|Distribuída a 1 c...|IND 26 2020 - IND...|Especial|        AGPAC|             MAPCO|             IND|Aguardando parece...|Aguardando apreci...|Administração Púb...|  INDICAÇÃO| moreka|        null|null|
# |             N|2020|   null|    20210224|Indica Dennys Gar...|Conselho Estadual|   20210224|            null|Governador Romeu ...|         null|    2020-03-12|    2021-02-04| Remissivo|  null|   1528|        null|Indicação, Membro...|            null|                   null|[{2021, mate, RQO...|[{2020, mate, MSG...|                      []|[{mate, Proposiçã...|     [{2021-02-04, Req...|          Arquivo|         |    25|000016451|Distribuída a 1 c...|IND 25 2020 - IND...|Especial|        RETRA|             MOUTR|             IND|Retirado de trami...|    Outras situações|Administração Púb...|  INDICAÇÃO| m20725|        null|null|
# |             N|2020|   null|        null|Indica Kátia Lili...|Conselho Estadual|   20220412|            null|Governador Romeu ...|         null|    2020-03-12|    2022-03-31|Tramitação|  null|   1038|        null|Indicação, Membro...|            null|                   null|                  []|[{2020, mate, MSG...|                      []|[{mate, Proposiçã...|     [{2022-03-31, Rem...|Comissão Especial|         |    24|000016452|Distribuída a 1 c...|IND 24 2020 - IND...|Especial|        AGDLC|             MAPCO|             IND|Aguardando diligê...|Aguardando apreci...|Administração Púb...|  INDICAÇÃO| moreka|        null|null|
# +--------------+----+-------+------------+--------------------+-----------------+-----------+----------------+--------------------+-------------+--------------+--------------+----------+------+-------+------------+--------------------+----------------+-----------------------+--------------------+--------------------+------------------------+--------------------+-------------------------+-----------------+---------+------+---------+--------------------+--------------------+--------+-------------+------------------+----------------+--------------------+--------------------+--------------------+-----------+-------+------------+----+
# only showing top 5 rows

# %%
df_final.printSchema()
# Out:
# root
#  |-- acompanhamento: string (nullable = true)
#  |-- ano: string (nullable = true)
#  |-- apelido: string (nullable = true)
#  |-- arquivamento: string (nullable = true)
#  |-- assunto: string (nullable = true)
#  |-- assuntoGeral: string (nullable = true)
#  |-- atualizacao: string (nullable = true)
#  |-- atualizacaoTexto: string (nullable = true)
#  |-- autor: string (nullable = true)
#  |-- classificacao: string (nullable = true)
#  |-- dataPublicacao: string (nullable = true)
#  |-- dataUltimaAcao: string (nullable = true)
#  |-- dominio: string (nullable = true)
#  |-- edicao: string (nullable = true)
#  |-- horario: string (nullable = true)
#  |-- horarioTexto: string (nullable = true)
#  |-- indexacao: string (nullable = true)
#  |-- legislacaoCitada: string (nullable = true)
#  |-- linkProposicaoAnexadora: struct (nullable = true)
#  |    |-- ano: long (nullable = true)
#  |    |-- banco: string (nullable = true)
#  |    |-- descricao: string (nullable = true)
#  |    |-- expressao: string (nullable = true)
#  |    |-- numero: long (nullable = true)
#  |    |-- tipo: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- links: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- ano: long (nullable = true)
#  |    |    |-- banco: string (nullable = true)
#  |    |    |-- descricao: string (nullable = true)
#  |    |    |-- expressao: string (nullable = true)
#  |    |    |-- numero: long (nullable = true)
#  |    |    |-- tipo: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- linksOrigem: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- ano: long (nullable = true)
#  |    |    |-- banco: string (nullable = true)
#  |    |    |-- descricao: string (nullable = true)
#  |    |    |-- expressao: string (nullable = true)
#  |    |    |-- numero: long (nullable = true)
#  |    |    |-- tipo: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- linksProposicoesAnexadas: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- ano: long (nullable = true)
#  |    |    |-- banco: string (nullable = true)
#  |    |    |-- descricao: string (nullable = true)
#  |    |    |-- expressao: string (nullable = true)
#  |    |    |-- numero: long (nullable = true)
#  |    |    |-- tipo: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- linksTextos: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- banco: string (nullable = true)
#  |    |    |-- descricao: string (nullable = true)
#  |    |    |-- expressao: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |-- listaHistoricoTramitacoes: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- data: string (nullable = true)
#  |    |    |-- historico: string (nullable = true)
#  |    |    |-- local: string (nullable = true)
#  |    |    |-- passo: long (nullable = true)
#  |-- local: string (nullable = true)
#  |-- matricula: string (nullable = true)
#  |-- numero: string (nullable = true)
#  |-- numeroDoc: string (nullable = true)
#  |-- observacao: string (nullable = true)
#  |-- proposicao: string (nullable = true)
#  |-- regime: string (nullable = true)
#  |-- siglaSituacao: string (nullable = true)
#  |-- siglaSituacaoGeral: string (nullable = true)
#  |-- siglaTipoProjeto: string (nullable = true)
#  |-- situacao: string (nullable = true)
#  |-- situacaoGeral: string (nullable = true)
#  |-- tema: string (nullable = true)
#  |-- tipoProjeto: string (nullable = true)
#  |-- usuario: string (nullable = true)
#  |-- usuarioTexto: string (nullable = true)
#  |-- nome: string (nullable = true)

# %%
# Tabela Proposicao
# id (incremental)
# author (string - Autor - ex. Governador Romeu Zema Neto)
# presentationDate (timestamp - Data de Apresentação - ex. 2022-10-06T00:00:00Z)
# ementa (string - Assunto - ex. Encaminha o Projeto de Lei 4008 2022, que dispõe sobre a revisão do Plano Plurianual de Ação Governamental - PPAG - 2020-2023, para o exercício de 2023.)
# regime (string - Regime - ex. Especial)
# situation (string - Situação - ex. Publicado)
# propositionType (string - Tipo da Proposição - ex. MSG)
# number (string - Numero - ex. 300)
# year (integer - Ano - ex. 2022)
# city (string -> fixo "Belo Horizonte")
# state (string -> fixo "Minas Gerais")

# Tabela Tramitacao
# id (incremental)
# createdAt (string - Data - ex. 2022-10-04T00:00:00Z)
# description (string - Histórico - Proposição lida em Plenário.\nPublicada no DL em 6 10 2022, pág 24.)
# local (string - Local - ex. Plenário)
# propositionId (chave estrangeira da proposição)

# %%
df_proposicao = df_final\
    .withColumn(
        'id_proposition', F.monotonically_increasing_id()
    )\
    .select(
        F.col('id_proposition'),
        F.col('autor').alias('author'),
        F.col('dataPublicacao').alias('presentationDate'),
        F.col('assunto').alias('ementa'),
        F.col('regime'),
        F.col('situacao').alias('situation'),
        F.col('siglaTipoProjeto').alias('propositiontype'),
        F.col('numero').alias('number'),
        F.col('ano').alias('year'),
        F.col('listaHistoricoTramitacoes').alias('tramitacoes')
    )\
    .withColumn(
        'presentationDate', F.to_timestamp(F.col('presentationDate'),'yyyy-mm-dd')
    )\
    .withColumn(
        'year', F.col('year').cast('integer')
    )\
    .withColumn(
        'city', F.lit('Belo Horizonte')
    )\
    .withColumn(
        'state', F.lit('Minas Gerais')
    )\
    .withColumn(
        'ementa', F.regexp_replace(F.col("ementa"), "\n|\r", " ")
    )\
    .withColumn(
        'tramitacoes',
        F.transform(
            F.col('tramitacoes'),
                    lambda x: F.struct(
                        F.monotonically_increasing_id().alias('id_tramitation'),
                        F.to_timestamp(x.data, 'yyyy-MM-dd').cast('string').alias('createdAt'),
                        F.regexp_replace(x.historico.alias('historico').alias('description'), "\n|\r", " "),
                        x.local.alias('local'),
                        F.col('id_proposition')
                    )
            )
    )

# %%
df_proposicao.show(5, truncate=False)
# Out:
# +--------------+--------------------------+-------------------+--------------------------------------------------------------------------------+--------+---------------------------------+---------------+------+----+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+------------